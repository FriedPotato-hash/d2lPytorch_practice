# %% [markdown]
# 그동안, 숫자 데이터와 이미지 데이터를 다루었습니다.
# 이미지 데이터의 경우에는 하나의 픽셀이 주위 픽셀들과 의미적인 관련성을 갖는다는 특성이 있었는데요. 이를 활용하기 위해 convolution 계산을 도입하는 것이 주된 연습 내용이었습니다.
#
# 그러나 세상에는 다양한 데이터들이 있죠.
# 시계열, sequence 데이터가 대표적인 예시가 되겠습니다.
# 주식 시장을 예측하거나 (주가를 예측하려는, 주식시장의 태동부터 함께한 인간의 덧없는 욕망이 되겠습니다.) 환자의 fever curve, 레이싱 자동차가 필요로 하는 가속도를 예측하는 task가 있겠죠.
#
# 즉, CNN이 spatial data, 공간적인 특성을 가진 데이터들을 잘 다뤄왔듯이, Recurrent neural networks (RNNs)을 통해서는 시계열 데이터를 잘 다룰 수 있다는 의미가 되겠습니다.
#
# Sequence data로는 대표적으로 'text'가 있으니, 그에 대해서도 배워보자구요~!
# 실용적인 전처리 기술과 베이직한 컨셉들을 배워보고, RNNs에 넣어 결과까지 도출해보겠습니다.

# %% [markdown]
# # 8.1.1. Statistical Tools
#
# ## 8.1.1.1. Autoregressive Models
#
# 시계열 데이터의 특징이 무엇인가요?
# 일단 입력 시퀀스의 길이가 예측하려는 시간에 따라 달라질 수 있겠다는 점.
#
# 문제를 해결하기 위해 제안된 첫 시도는, 그냥 인풋으로 받을 수 있는 길이를 무진장 늘려놓는 것입니다. 필요 이상으로요. 딱 봐도 별로 안좋을 것 같죠..?
#
# 그래서 제안된게 두번째!
# 바로 recurrent 한 모델을 만드는 것입니다.
# h_t라는 hidden state를 두는데, 이는 이전 t 시점에서 계산됐던 값 또한 입력값으로 받습니다.
#
# 다음 식과 그림을 확인하고 넘어갈게요!
#
# 𝑥̂_𝑡=𝑃(𝑥_𝑡∣ℎ_𝑡),,,,  ℎ𝑡=𝑔(ℎ𝑡−1,𝑥𝑡−1)
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8.1.1.2. Markov Models
#
# ## 8.1.1.3. Causality

# %% [markdown]
# # 8.1.2. Training

# %%
# %matplotlib inline
import torch
from torch import nn
from d2l import torch as d2l

T = 1000
time = torch.arange(1, T+1, dtype=torch.float32)
x = torch.sin(0.01*time) + torch.normal(0, 0.3, (T,))
d2l.plot(time, [x], 'time', 'x', xlim=[1,1000], figsize=(6,3))

# %%
tau = 4
features = torch.zeros((T-tau, tau))

for i in range(tau):
    features[:,i] = x[i:T-tau+i]
labels = x[tau:].reshape((-1, 1))

batch_size, n_train = 16, 600
# Only the first `n_train` examples are used for training
train_iter = d2l.load_array((features[:n_train], labels[:n_train]),
                            batch_size, is_train=True)

# Function for initializing the weights of the network
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)

# A simple MLP
def get_net():
    net = nn.Sequential(nn.Linear(4, 10),
                        nn.ReLU(),
                        nn.Linear(10, 1))
    net.apply(init_weights)
    return net

# Note: `MSELoss` computes squared error without the 1/2 factor
loss = nn.MSELoss(reduction='none')

# %%
def train(net, train_iter, loss, epochs, lr):
    trainer = torch.optim.Adam(net.parameters(), lr)
    for epoch in range(epochs):
        for X, y in train_iter:
            trainer.zero_grad()
            l = loss(net(X), y)
            l.sum().backward()
            trainer.step()
        print(f'epoch {epoch + 1}, '
              f'loss: {d2l.evaluate_loss(net, train_iter, loss):f}')

net = get_net()
train(net, train_iter, loss, 5, 0.01)
# Out:
# epoch 1, loss: 0.130544
# epoch 2, loss: 0.116578
# epoch 3, loss: 0.108546
# epoch 4, loss: 0.106766
# epoch 5, loss: 0.112461

# %%
onestep_preds = net(features)
d2l.plot([time, time[tau:]], [x.detach().numpy(), onestep_preds.detach().numpy()], 'time',
         'x', legend=['data', '1-step preds'], xlim=[1, 1000], figsize=(6, 3))
